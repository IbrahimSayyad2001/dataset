# %% [markdown]
# <a href="https://colab.research.google.com/github/IbrahimSayyad2001/dataset/blob/main/ipl2024scheduledataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
d = {
    "Match No": list(range(1, 22)),
    "Day": ["Fri", "Sat", "Sat", "Sun", "Sun", "Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun", "Sun", "Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun", "Sun"],
    "Date": ["22-03-2024", "23-03-2024", "23-03-2024", "24-03-2024", "24-03-2024", "25-03-2024", "26-03-2024", "27-03-2024", "28-03-2024", "29-03-2024", "30-03-2024", "31-03-2024", "31-03-2024", "01-04-2024", "02-04-2024", "03-04-2024", "04-04-2024", "05-04-2024", "06-04-2024", "07-04-2024", "07-04-2024"],
    "Match": ["CSK vs RCB", "PBKS vs DC", "KKR vs SRH", "RR vs LSG", "GT vs MI", "RCB vs PBKS", "CSK vs GT", "SRH vs MI", "RR vs DC", "RCB vs KKR", "LSG vs PBKS", "GT vs SRH", "DC vs CSK", "MI vs RR", "RCB vs LSG", "DC vs KKR", "GT vs PBKS", "SRH vs CSK", "RR vs RCB", "MI vs DC", "LSG vs GT"],
    "Time (IST)": ["8:00 PM", "3:30 PM", "7:30 PM", "3:30 PM", "7:30 PM", "7:30 PM", "7:30 PM", "7:30 PM", "7:30 PM", "7:30 PM", "7:30 PM", "3:30 PM", "7:30 PM", "7:30 PM", "7:30 PM", "7:30 PM", "7:30 PM", "7:30 PM", "7:30 PM", "3:30 PM", "7:30 PM"],
    "Venue": ["Chennai", "Mohali", "Kolkata", "Jaipur", "Ahmedabad", "Bengaluru", "Chennai", "Hyderabad", "Jaipur", "Bengaluru", "Lucknow", "Ahmedabad", "Visakhapatnam", "Mumbai", "Bengaluru", "Visakhapatnam", "Ahmedabad", "Hyderabad", "Jaipur", "Mumbai", "Lucknow"],
}

# %%
df=pd.DataFrame(d)

# %%
np.random.seed(0)
adult_ticket_rate = np.random.randint(1200, 3001,size=len(df))
num_adult_tickets = np.random.randint(1, 2000, size=len(df))
senior_ticket_rate = np.random.randint(800, 1501,size=len(df))
num_senior_tickets = np.random.randint(0, 50, size=len(df))
child_ticket_rate = np.random.randint(500, 1001,size=len(df))
num_child_tickets = np.random.randint(0, 200, size=len(df))
vip_ticket_rate = np.random.randint(5000, 10001, size=len(df))
num_vip_ticket = np.random.randint(0,300 ,size=len(df))
corporate_ticket_rate = np.random.randint(4000, 8001, size=len(df))
num_corporate_ticket=np.random.randint(0,250,size=len(df))
student_ticket_rate = np.random.randint(700, 2501, size=len(df))
num_student_ticket=np.random.randint(0,400,size=len(df))

#np.random.seed(42)

# %%
df['Adult Ticket Rate'] = adult_ticket_rate
df['Number of Adult Tickets'] = num_adult_tickets

df['Senior Ticket Rate'] = senior_ticket_rate
df['Number of Senior Tickets'] = num_senior_tickets

df['Child Ticket Rate'] = child_ticket_rate
df['Number of Child Tickets'] = num_child_tickets

df['VIP Ticket Rate'] = vip_ticket_rate
df['Number of Vip Tickets'] = num_vip_ticket

df['Corporate Ticket Rate'] = corporate_ticket_rate
df['Number of Corporate Tickets'] = num_corporate_ticket

df['Student Ticket Rate'] = student_ticket_rate
df['Number of Student Tickets'] = num_student_ticket

# %%
df["Total_number_of_tickets_sell"]=(df['Number of Adult Tickets']+df['Number of Senior Tickets'] +df['Number of Child Tickets']+df['Number of Vip Tickets']+df['Number of Corporate Tickets']+df['Number of Student Tickets'])

# %%
df.columns
# Out:
# Index(['Match No', 'Day', 'Date', 'Match', 'Time (IST)', 'Venue',
#        'Adult Ticket Rate', 'Number of Adult Tickets', 'Senior Ticket Rate',
#        'Number of Senior Tickets', 'Child Ticket Rate',
#        'Number of Child Tickets', 'VIP Ticket Rate', 'Number of Vip Tickets',
#        'Corporate Ticket Rate', 'Number of Corporate Tickets',
#        'Student Ticket Rate', 'Number of Student Tickets'],
#       dtype='object')

# %%
df
# Out:
#     Match No  Day        Date        Match Time (IST)          Venue  \
# 0          1  Fri  22-03-2024   CSK vs RCB    8:00 PM        Chennai
# 1          2  Sat  23-03-2024   PBKS vs DC    3:30 PM         Mohali
# 2          3  Sat  23-03-2024   KKR vs SRH    7:30 PM        Kolkata
# 3          4  Sun  24-03-2024    RR vs LSG    3:30 PM         Jaipur
# 4          5  Sun  24-03-2024     GT vs MI    7:30 PM      Ahmedabad
# 5          6  Mon  25-03-2024  RCB vs PBKS    7:30 PM      Bengaluru
# 6          7  Tue  26-03-2024    CSK vs GT    7:30 PM        Chennai
# 7          8  Wed  27-03-2024    SRH vs MI    7:30 PM      Hyderabad
# 8          9  Thu  28-03-2024     RR vs DC    7:30 PM         Jaipur
# 9         10  Fri  29-03-2024   RCB vs KKR    7:30 PM      Bengaluru
# 10        11  Sat  30-03-2024  LSG vs PBKS    7:30 PM        Lucknow
# 11        12  Sun  31-03-2024    GT vs SRH    3:30 PM      Ahmedabad
# 12        13  Sun  31-03-2024    DC vs CSK    7:30 PM  Visakhapatnam
# ...

# %%
df.to_csv('IPL schedule for 2024 ')
